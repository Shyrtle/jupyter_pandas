# %%
# %%cmd
# pip install yfinance
# Out:
# Microsoft Windows [Version 10.0.18362.778]
# (c) 2019 Microsoft Corporation. All rights reserved.
#
# (base) C:\Users\jhemsley>pip install yfinance
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22414 sha256=54b0bb520ec5a7c927bb4787c7e55fd4f08b829493c11c7b09f3dd34f9a1bd4a
#   Stored in directory: C:\Users\jhemsley\AppData\Local\pip\Cache\wheels\f9\e3\5b\ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-cp37-none-any.whl size=8373 sha256=259e6862f53287b0cf285dc72e341bc8a9de2c55d1d3893f61e6f3b78ccf2c08
#   Stored in directory: C:\Users\jhemsley\AppData\Local\pip\Cache\wheels\37\fa\73\d492849e319038eb4d986f5152e4b19ffb1bc0639da84d2677
# Successfully built yfinance multitasking
# ...
#
# (base) C:\Users\jhemsley>

# %%
import yfinance as yf
import pandas as pd

# %%
msft = yf.Ticker("MSFT")

# %%
print(msft)
# Out:
# yfinance.Ticker object <MSFT>

# %%
msft.info
# Out:
# {'zip': '98052',
#  'sector': 'Technology',
#  'fullTimeEmployees': 144000,
# ...

# %%
msft.history(period="max")
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.07    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# ...            ...     ...     ...     ...         ...        ...
# 2020-04-21  173.50  173.67  166.11  167.82    56203700        0.0
# 2020-04-22  171.39  174.00  170.82  173.52    34651600        0.0
# 2020-04-23  174.11  175.06  170.91  171.42    32790800        0.0
# 2020-04-24  172.06  174.56  170.71  174.55    34277600        0.0
# 2020-04-27  176.59  176.90  173.38  174.05    32105711        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0
# ...

# %%
df = pd.DataFrame(msft.history(period="max"))

# %%
df
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.07    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# ...            ...     ...     ...     ...         ...        ...
# 2020-04-21  173.50  173.67  166.11  167.82    56203700        0.0
# 2020-04-22  171.39  174.00  170.82  173.52    34651600        0.0
# 2020-04-23  174.11  175.06  170.91  171.42    32790800        0.0
# 2020-04-24  172.06  174.56  170.71  174.55    34277600        0.0
# 2020-04-27  176.59  176.90  173.38  174.05    32105711        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8601 entries, 1986-03-13 to 2020-04-27
# Data columns (total 7 columns):
# Open            8601 non-null float64
# High            8601 non-null float64
# Low             8601 non-null float64
# Close           8601 non-null float64
# Volume          8601 non-null int64
# Dividends       8601 non-null float64
# Stock Splits    8601 non-null float64
# dtypes: float64(6), int64(1)
# memory usage: 537.6 KB

# %%
df.plot(x=pd.Index, y="Close", kind="scatter", figsize=(20,20), use_index=True, title="Hey", style="dict", legend=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-029dd6dd79aa> in <module>
# ----> 1 df.plot(x=pd.Index, y="Close", kind="scatter", figsize=(20,20), use_index=True, title="Hey", style="dict", legend=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59                 ax = plt.gca()
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
pd.Index
# Out:
# pandas.core.indexes.base.Index

# %%
df.pd.Index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-6438d10d7e5d> in <module>
# ----> 1 df.pd.Index
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'pd'

# %%
df.set_index([0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-e4f4f55fd670> in <module>
# ----> 1 df.set_index([0])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4409
#    4410         if missing:
# -> 4411             raise KeyError("None of {} are in the columns".format(missing))
#    4412
#    4413         if inplace:
#
# KeyError: 'None of [0] are in the columns'
